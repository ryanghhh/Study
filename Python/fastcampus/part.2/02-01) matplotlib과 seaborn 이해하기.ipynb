# %% [markdown]
# # **matplotlib과 seaborn 이해하기**
#
#
# ---

# %% [markdown]
# - **`matplotlib`**: 파이썬 데이터 시각화의 가장 기본적인 라이브러리. 유연하게 커스텀이 가능하나 코드가 길고 어렵다는 단점이 있습니다.
# - **`seaborn`**: **`matplotlib`**을 좀 더 쉽고 아름답게 시각화하는 라이브러리
# - 실제 분석에서는 **`seaborn`**과 **`matplotlib`**을 함께 사용하여 시각화하는 경우가 많습니다.

# %% [markdown]
# ## **[1] 기본 문법**
# ```
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# plt.figure(figsize=(가로길이, 세로길이)) #그래프 크기 설정
# *필수* sns.000plot(data=데이터, x=X축 컬럼, y=Y축 컬럼, hue=범례 컬럼) #seaborn으로 그래프 그리기
# plt.title(제목) #제목 설정
# plt.xlabel(라벨) #x축 라벨 설정
# plt.ylabel(라벨) #y축 라벨 설정
# plt.legend(loc=범례 위치 설정)
# plt.xticks(rotation=x축 각도 설정)
# plt.yticks(rotation=y축 각도 설정)
# plt.show() #그래프 출력
# ```

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.barplot(data=df, x='species', y='body_mass_g')
## sns.barplot()은 기본적으로 평균(mean)을 계산하여 막대그래프를 그린다.
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=df, x='species', y='body_mass_g')
plt.title('body mass per species')
plt.xlabel('per species')
plt.ylabel('body mass')
plt.show()

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.barplot(data=df, x="island", y="body_mass_g", hue="sex")
plt.show()

# %%
sns.barplot(data=df, x="island", y="body_mass_g", hue="sex")
plt.xticks(rotation=30) ## x축 레이블을 30도 회전
plt.legend(loc='upper left')  ## 범례 위치를 왼쪽 위로 설정
plt.show()

# %% [markdown]
# ## **[2] 스타일 설정하기**
#
# ```
# sns.set_style(스타일)
# sns.set_palette(팔레트)
# ```
# - 스타일: darkgrid, whitegrid, dark, white
# - 팔레트: [참고](https://seaborn.pydata.org/tutorial/color_palettes.html)

# %%
import seaborn as sns

print(sns.get_dataset_names())  ## seaborn에서 제공하는 데이터셋 목록 출력
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
sns.set_style('white')
## sns.set_palette('rocket')
sns.barplot(data=df, x='species', y='body_mass_g', hue='species', 
            palette=['#FF90BB', '#FFC1DA', '#8ACCD5'])

plt.show()

# %%
sns.set_style('whitegrid')
sns.barplot(data=df, x='species', y='body_mass_g')
plt.show()

# %%
sns.set_style('white')
sns.barplot(data=df, x='species', y='body_mass_g')
plt.show()

# %%
sns.set_style('dark')
sns.barplot(data=df, x='species', y='body_mass_g')
plt.show()

# %%
sns.set_palette('Set3')
sns.barplot(data=df, x='species', y='body_mass_g')
plt.show()

# %%
sns.set_style('white')
sns.set_palette('flare')
sns.barplot(data=df, x='species', y='body_mass_g')
plt.show()

# %%
sns.set_palette('crest')
sns.barplot(data=df, x='species', y='body_mass_g')
plt.show()

# %% [markdown]
# ## **[3] 한글 폰트 설정**
#
#
#
# 1.   폰트 설치
#
# ```
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# ```
#
# 2.   런타임 다시 시작
# 3.   폰트 적용
#
# ```
# plt.rc('font', family='NanumGothic')
# ```

# %%
#한글 폰트 미적용시
sns.barplot(data=df, x='species', y='body_mass_g')
plt.title('펭귄의 종별 몸무게')
plt.show()
# Out:
# C:\Users\ryang\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54189 (\N{HANGUL SYLLABLE PENG}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ryang\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44484 (\N{HANGUL SYLLABLE GWIN}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ryang\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ryang\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns

# %%
import os

font_dir = 'C:/Windows/Fonts'
for file in os.listdir(font_dir):
    if file.lower().endswith('.ttf'):
        print(file)
# Out:
# AGENCYB.TTF
# AGENCYR.TTF
# ALGER.TTF
# ANTQUAB.TTF
# ANTQUABI.TTF
# ANTQUAI.TTF
# arial.ttf
# arialbd.ttf
# arialbi.ttf
# ariali.ttf
# ARIALN.TTF
# ARIALNB.TTF
# ARIALNBI.TTF
# ARIALNI.TTF
# ariblk.ttf
# ARLRDBD.TTF
# bahnschrift.ttf
# BASKVILL.TTF
# BAUHS93.TTF
# BELL.TTF
# BELLB.TTF
# BELLI.TTF
# BERNHC.TTF
# BKANT.TTF
# BOD_B.TTF
# BOD_BI.TTF
# BOD_BLAI.TTF
# BOD_BLAR.TTF
# BOD_CB.TTF
# BOD_CBI.TTF
# BOD_CI.TTF
# BOD_CR.TTF
# BOD_I.TTF
# BOD_PSTC.TTF
# BOD_R.TTF
# BOOKOS.TTF
# BOOKOSB.TTF
# BOOKOSBI.TTF
# BOOKOSI.TTF
# BRADHITC.TTF
# BRITANIC.TTF
# BRLNSB.TTF
# BRLNSDB.TTF
# BRLNSR.TTF
# BROADW.TTF
# BRUSHSCI.TTF
# BSSYM7.TTF
# calibri.ttf
# calibrib.ttf
# calibrii.ttf
# calibril.ttf
# calibrili.ttf
# calibriz.ttf
# CALIFB.TTF
# CALIFI.TTF
# CALIFR.TTF
# CALIST.TTF
# CALISTB.TTF
# CALISTBI.TTF
# CALISTI.TTF
# cambriab.ttf
# cambriai.ttf
# cambriaz.ttf
# Candara.ttf
# Candarab.ttf
# Candarai.ttf
# Candaral.ttf
# Candarali.ttf
# Candaraz.ttf
# CASTELAR.TTF
# CENSCBK.TTF
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager

font_path = 'C:/Windows/Fonts/malgun.ttf'
font_name = font_manager.FontProperties(fname=font_path).get_name()
plt.rcParams['font.family'] = font_name
plt.plot([1, 2, 3], [1, 4, 9])
plt.title('한글 표시 테스트')
plt.show()

# %%
from matplotlib import font_manager

## 한글 출력 가능한 문자들 찾기

# 한글 테스트용 문자
test_char = '가'

# 한글이 포함된 폰트만 추출
hangul_fonts = []

for font_path in font_manager.findSystemFonts(fontpaths=None):
    try:
        font_prop = font_manager.FontProperties(fname=font_path)
        font_name = font_prop.get_name()
        if font_manager.FontProperties(fname=font_path).get_size_in_points() is not None:
            # 한글을 표시할 수 있는지 검사
            if font_manager.get_font(font_path).get_char_index(ord(test_char)) != 0:
                hangul_fonts.append((font_name, font_path))
    except Exception:
        continue

# 결과 출력
for name, path in hangul_fonts:
    print(f'{name}: {path}')
# Out:
# SUIT: C:\Users\ryang\AppData\Local\Microsoft\Windows\Fonts\SUIT-ExtraBold.ttf
# Noto Sans KR: C:\Windows\Fonts\NotoSansKR-VF.ttf
# NanumGothic: C:\Users\ryang\AppData\Local\Microsoft\Windows\Fonts\NanumGothicBold.ttf
# Noto Sans KR: C:\Users\ryang\AppData\Local\Microsoft\Windows\Fonts\NotoSansKR-VF_0.ttf
# NanumHuman TTF: C:\Users\ryang\AppData\Local\Microsoft\Windows\Fonts\NanumHumanEB.ttf
# KoPubWorldDotum: C:\Users\ryang\AppData\Local\Microsoft\Windows\Fonts\KoPubWorld Dotum Bold.ttf
# KoPubWorldBatang: C:\Users\ryang\AppData\Local\Microsoft\Windows\Fonts\KoPubWorld Batang Bold.ttf
# Yet R: C:\Windows\Fonts\HMFMOLD.TTF
# NanumHuman TTF: C:\Users\ryang\AppData\Local\Microsoft\Windows\Fonts\NanumHumanRegular.ttf
# Noto Serif KR: C:\Users\ryang\AppData\Local\Microsoft\Windows\Fonts\NotoSerifKR-VF_0.ttf
# NanumHuman TTF: C:\Users\ryang\AppData\Local\Microsoft\Windows\Fonts\NanumHumanLight.ttf
# HYMyeongJo-Extra: C:\Windows\Fonts\H2MJRE.TTF
# ...

# %%
font_path = r'C:\Users\ryang\AppData\Local\Microsoft\Windows\Fonts\SUIT-Bold_0.ttf'
font_prop = font_manager.FontProperties(fname=font_path)
print(font_prop.get_name())

## 지정한 폰트 파일(.ttf 또는 .otf)이 어떤 이름의 폰트로 등록되어 있는지 확인하는 것
# Out:
# SUIT

# %%
## 폰트 설치했는데도 안될 경우 이 코드로 경로 확인해서 해당 경로의 json 파일 삭제하면 된다.
import matplotlib as mpl
print(mpl.get_cachedir())
# Out:
# C:\Users\ryang\.matplotlib

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager
import seaborn as sns

## 경로는 
font_path = r'C:\Users\ryang\AppData\Local\Microsoft\Windows\Fonts\Pretendard-ExtraBold.ttf'
font_prop = font_manager.FontProperties(fname=font_path)

font_path_1 = r'C:\Windows\Fonts\HMFMPYUN.TTF'
font_prop_1 = font_manager.FontProperties(fname=font_path_1)

font_path_2 = r'C:\Windows\Fonts\gulim.ttc'
font_prop_2 = font_manager.FontProperties(fname=font_path_2)

# 실제 폰트 이름 확인
#font_name = font_prop.get_name()
#print("폰트 이름:", font_name)

# 적용
#plt.rcParams['font.family'] = font_name
sns.set_palette('pink_r') ## 차트 그리기 전에 설정하기
sns.set_style('whitegrid')
# %config InlineBackend.figure_format = 'retina'
sns.barplot(data=df, x='species', y='body_mass_g', hue='species')
 ##hue는 색상 구분자 역할. x만 있고 hue가 없으면 → Seaborn은 “하나의 데이터 그룹”이라고 판단해서 색 하나만 씀)

##plt.title('펭귄의 종별 몸무게')
plt.title('펭귄의 종별 몸무게', fontproperties=font_prop)  ## 실험결과 이렇게 폰트를 직접 박아줘야 폰트가 바뀌었다....
plt.xlabel('종 이름', fontproperties=font_prop_1)
plt.ylabel('몸무게 (g)', fontproperties=font_prop_2)
plt.show()

# %%
## 선생님방식. 그러나 다운받은 폰트들은 이 방식 적용잘 안됨.

plt.rc('font', family='NanumGothic')
sns.set_palette('pink_r')

sns.barplot(data=df, x='species', y='body_mass_g')
plt.title('펭귄의 종별 몸무게')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# 샘플 데이터
df = pd.DataFrame({
    'species': ['Adelie', 'Chinstrap', 'Gentoo'],
    'body_mass_g': [3700, 3500, 5000]
})

sns.set_style('whitegrid')
sns.set_palette('Set2')

# hue 추가!
sns.barplot(data=df, x='species', y='body_mass_g', hue='species')
plt.title('펭귄 종별 몸무게')
plt.show()
# Out:
# C:\Users\ryang\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54189 (\N{HANGUL SYLLABLE PENG}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ryang\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44484 (\N{HANGUL SYLLABLE GWIN}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ryang\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ryang\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ## **[4] 고화질 설정**
#
#
# ```
# %config InlineBackend.figure_format = 'retina'
# ```

# %%
# %config InlineBackend.figure_format = 'retina'
sns.barplot(data=df, x='species', y='body_mass_g', hue='species')
plt.title('펭귄의 종별 몸무게', fontproperties=font_prop)
plt.show()
