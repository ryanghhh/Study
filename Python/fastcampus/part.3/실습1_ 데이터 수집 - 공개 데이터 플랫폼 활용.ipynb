# %% [markdown]
# # **공개 데이터 플랫폼 활용**

# %% [markdown]
# ## [1] 국내 사이트

# %% [markdown]
# [1. 서울 열린데이터광장](https://data.seoul.go.kr/)
#
# [2. 공공데이터포털](https://www.data.go.kr)
#
# [3. 통계청](http://kostat.go.kr/)

# %% [markdown]
# ## [2] 해외 사이트

# %% [markdown]
# [1. 캐글](https://www.kaggle.com/datasets)
#
# [2. awesomedata](https://github.com/awesomedata/awesome-public-datasets)
