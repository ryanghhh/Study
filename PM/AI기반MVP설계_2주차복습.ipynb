# %%
오늘은 2주차 수업으로 PM으로서 좋은 근거는 어떻게 세우는지에 관하여 배웠다.

PM이 활용하는 근거는 아래의 4가지 유형의 근거가 있으며
여러 유형의 근거를 복합적으로 활용해야 한다

1. 데이터 근거(가장 강력하다)
- AB테스트
- 샘플 사이즈는 클수록 신뢰도가 높아진다
- 신뢰수준 95% (이 결과가 우연이 아닐 확률이 95%)

2. 유저 리서치 근거
- 정성 데이터
- 반복되는 키워드, 공통되는 의견에 주목
- 인터뷰 정리 (WORD CLUD, 친화도 다이어그램) 통해 공통된 주제로 정리

3. 비즈니스 근거
- MOM, YOY, WOW
- 시장 전체의 트래드 읽기 (경쟁사)
- 세그먼트별로 나누어 현황 분석

4. 제약 조건 근거
- 스프린트 : 정해진 기간 동안 완료해야할 작업 집중적 수행 주기
- 스토리 포인트 : 작업의 난이도와 소요 시간 숫자로 시각화
- 기술부채 : 대충 작업한 작업물은 추후 이자를 지불하고 갚아야 함

좋은 근거
- 구체적 숫자가 있다
- 출처가 명확
- 반박 가능하다 ; 건강한 토론, 그만큼 나의 근거가 구체적이라는 뜻, 긍정적 신호다

문제를 정의할때는 무엇을 해결해야 하는지부터 명확해야 한다
누가, 언제, 무엇을 못해서, 어떤 결과가 나타났는지 분해해보기
