# %%
데이터 분석 - NotebookLM 활용
- 구체적 데이터 분석 (내가 업로드한 자료 내에서만)
- 구체적 출처 (내가 업로드한 자료 내에서만)

너무 많은 데이터를 입력할 경우
- 역U자형 성능 곡선 
- Lost in Middle (중간 내용 망각)
- 너무 긴 정보보다 정돈된 짧은 정보가 더 정확

리뷰 분석 순서
1. 패턴 파악
Analyze reviews to find consistent themes
Focus on negative reviews first.
"for each theme, show me specific quotes with citations."
통해서 연관된 리뷰끼리 그룹화 한다.

2. 가설 검증 - 확증 편향을 줄이고 필요한 데이터만 가지고 갈 수 있도록 필터링
Identify wrong product assumptions.
"If we assumed 'users trust our ETA', what evidence contradicts this?"

3. 우선 순위 배분
AI의 분석에 따라 빈도, 감정, 가치를 종합하여 우선순위 책정

4. 문제 정의
누가, 언제, 무엇을, 현재 상황 파악

5. 문제 정의를 더 견고하게 만드는 반박 포인트 점검



AI가 하는것 (what)
- 리뷰에서 테마 추출
- 텍스트기반 1차 검증
- 이슈 빈도 따른 우선 순위 제안
- 문제 정의 초안 작성

PM이 해야 하는 것(decision)
- 임팩트 사이징 (얼마나 큰 문제인가, 막연한 문제를 구체적인 숫자로 치환)
- 근본 원인 가설 (진짜 원인은 무엇인가, 현상을 넘어 원인을 찾고 그에 맞는 솔루션 매핑)
- 스코프 바운더리 (이번엔 무엇을 해결하고 무엇을 포기할것인가)
- 성공 지표 (해결 여부 검증 도구)
