# %% [markdown]
# # **라이브러리 사용**
#
# ---

# %% [markdown]
# ## **[1] 라이브러리란?**
#  - 다른 사람들이 만들어 둔 유용한 함수들의 모음
#  - 자주 사용하는 기능을 쉽게 재사용할 수 있고 다른 사람과도 그 기능을 공유할 수 있습니다.
#  - 표준 라이브러리: 파이썬을 설치할 때 자동으로 설치됩니다.
#  - 외부 라이브러리: 기본으로 설치된 라이브러리가 아니므로 새로 설치해 주어야 합니다.
#
#
#     import 라이브러리명
#
# - 외부 라이브러리를 다운 받으려면
#
#
#     !pip install 라이브러리명

# %% [markdown]
# ## **[2] 살펴볼 라이브러리**
# - `random`
# - `datetime`
# - `math`
# - `numpy`
# - `Counter`

# %% [markdown]
# ## `random`
# |함수명|설명|
# |:--|:--|
# |random()| 0~1 사이의 실수형의 수를 반환합니다.|
# |randint(시작, 끝)| 특정 범위 안의 랜덤한 정수를 반환합니다.|
# |random.choice(리스트)| 리스트 중에 랜덤하게 요소를 뽑습니다.|
# |random.sample(리스트, 갯수)| 리스트 중 입력한 갯수만큼 랜덤하게 요소를 뽑습니다.|
# |random.shuffle(리스트)| 리스트를 랜덤하게 섞습니다.|

# %%
random()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 random()
#
# NameError: name 'random' is not defined

# %%
import random

random.random()
# Out:
# 0.8063125402169389

# %%
random.randint(1, 1000)

# %%
a = [i for i in range(5)]
random.choice(a)
# Out:
# 4

# %%
random.sample(a, 2)
# Out:
# [3, 4]

# %%
random.shuffle(a)
print(a)
# Out:
# [0, 1, 4, 2, 3]

# %% [markdown]
# ## `datetime`
# - `datetime` 클래스: 날짜와 시간을 저장합니다.
#
# |함수|설명|
# |:--|:--|
# |now()|현재 시각을 반환합니다. (timezone에 유의합니다.)|
# |year, month, day, hour, minute, second, microsecond|날짜, 시간 값을 반환합니다.|
# |date()| 연월일로 이루어진 날짜 객체를 반환합니다.|
# |time()|시간 객체를 반환합니다.|
# |strftime('날짜형식')| 날짜와 시간 정보를 문자열로 변환합니다.|
# |strptime(문자열, 날짜형식)|문자열을 날짜로 변환합니다.|
#
# - `timedelta` 클래스: 시간 구간을 저장하며 날짜 연산을 할 때 쓰입니다.

# %%
from datetime import datetime
from pytz import timezone
from datetime import timedelta

# %%
print(datetime.now())
print(datetime.now(timezone('UTC')))
print(datetime.now(timezone('Asia/Seoul')))
# Out:
# 2025-04-24 22:06:08.699598
# 2025-04-24 13:06:08.700324+00:00
# 2025-04-24 22:06:13.871970+09:00

# %%
x = datetime.now(timezone('Asia/Seoul'))
print(x)
print(x.year, x.month, x.day, x.hour, x.minute, x.second, x.microsecond)
print(x.date(), x.time())
print(x.weekday()) # {0:월, 1:화, 2:수, 3:목, 4:금, 5:토, 6:일}
# Out:
# 2025-04-24 22:06:27.785104+09:00
# 2025 4 24 22 6 27 785104
# 2025-04-24 22:06:27.785104
# 3

# %%
x.strftime('%Y-%m-%d')
# Out:
# '2025-04-24'

# %%
x.strftime('%Y%m%d')
# Out:
# '20250424'

# %%
x.strftime('%Y/%m')
# Out:
# '2025/04'

# %%
datetime.strptime('2023-05-01', '%Y-%m-%d')
# Out:
# datetime.datetime(2023, 5, 1, 0, 0)

# %%
x
# Out:
# datetime.datetime(2025, 4, 24, 22, 6, 27, 785104, tzinfo=<DstTzInfo 'Asia/Seoul' KST+9:00:00 STD>)

# %%
x - timedelta(days=7)
# Out:
# datetime.datetime(2025, 4, 17, 22, 6, 27, 785104, tzinfo=<DstTzInfo 'Asia/Seoul' KST+9:00:00 STD>)

# %%
(x + timedelta(days=30)).strftime('%Y-%m-%d')
# Out:
# '2025-05-24'

# %%
from dateutil.relativedelta import relativedelta

x - relativedelta(months=1)
# Out:
# datetime.datetime(2025, 3, 24, 22, 6, 27, 785104, tzinfo=<DstTzInfo 'Asia/Seoul' KST+9:00:00 STD>)

# %%
x + relativedelta(years=2)
# Out:
# datetime.datetime(2027, 4, 24, 22, 6, 27, 785104, tzinfo=<DstTzInfo 'Asia/Seoul' KST+9:00:00 STD>)

# %% [markdown]
# ## `math`
#
# |함수|	설명|
# |:--|:--|
# |math.pi|	원주율|
# |math.e|	자연상수|
# |abs()|	절댓값(내장함수)|
# |round()|	반올림(내장함수)|
# |math.ceil()|올림|
# |math.floor()|내림|
# |math.factorial()|	팩토리얼|
# |math.pow()|	제곱 연산|
# |math.sqrt()|	제곱근 연산|

# %%
import math

math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
abs(-314)
# Out:
# 314

# %%
round(2.123, 2)
# Out:
# 2.12

# %%
math.ceil(2.124)
# Out:
# 3

# %%
math.floor(2.124)
# Out:
# 2

# %%
math.factorial(5)
# Out:
# 120

# %%
math.pow(5, 3)
# Out:
# 125.0

# %%
math.sqrt(25)
# Out:
# 5.0

# %% [markdown]
# ## `numpy`
# - 벡터 / 행렬 연산을 도와주는 라이브러리

# %%
import numpy as np

# %%
ls = random.sample([i for i in range(1000)],100)

# %%
print(np.mean(ls))
print(np.var(ls))
print(np.std(ls))
print(np.sum(ls))
# Out:
# 499.67
# 86343.74110000001
# 293.84305521825763
# 49967

# %% [markdown]
# ## Counter

# %%
from collections import Counter

ls = ['a','a','b','b','b','c','d','d','d','d']
Counter(ls)
# Out:
# Counter({'d': 4, 'b': 3, 'a': 2, 'c': 1})

# %%
count_dic = Counter(ls)
print(count_dic.most_common())
print(count_dic.most_common(1))
print(count_dic.most_common(2))
# Out:
# [('d', 4), ('b', 3), ('a', 2), ('c', 1)]
# [('d', 4)]
# [('d', 4), ('b', 3)]
